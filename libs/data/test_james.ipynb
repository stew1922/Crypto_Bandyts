# %%
#testing crypto_prices2.csv
#data is here, fills in at diff times because perhaps cryptos came on kraken at diff time periods

import pandas as pd
import sqlite3

# %%
#test pull from .csv
# data_crypto_ohlc = pd.read_csv('../data/crypto_prices2.csv')
pd.set_option("display.max_rows", None, "display.max_columns", None)
print (data_crypto_ohlc)
# Out:
#                     Date  Open_XXBTZ  High_XXBTZ  Low_XXBTZ  Close_XXBTZ  \
# 0    2019-01-20 18:00:00      3534.8      3565.0     3488.0       3533.4
# 1    2019-01-21 18:00:00      3531.7      3607.5     3440.0       3575.8
# 2    2019-01-22 18:00:00      3575.7      3613.2     3524.2       3556.1
# 3    2019-01-23 18:00:00      3556.1      3591.0     3531.3       3568.3
# 4    2019-01-24 18:00:00      3571.2      3576.6     3511.6       3560.0
# 5    2019-01-25 18:00:00      3560.0      3673.0     3535.6       3556.2
# 6    2019-01-26 18:00:00      3555.8      3562.2     3470.8       3531.3
# 7    2019-01-27 18:00:00      3533.5      3537.0     3373.8       3431.0
# 8    2019-01-28 18:00:00      3431.0      3439.1     3344.5       3395.0
# 9    2019-01-29 18:00:00      3390.5      3465.1     3371.3       3436.9
# 10   2019-01-30 18:00:00      3435.1      3478.1     3395.2       3409.6
# 11   2019-01-31 18:00:00      3409.6      3460.0     3373.5       3437.2
# ...

# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("../notebooks/DB_kraken.db")
df = pd.read_sql_query("SELECT * from crypto_ohlc", con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
#                   date  open_xxbtz  high_xxbtz  low_xxbtZ  close_xxbtz  \
# 0  2019-01-20 18:00:00      3534.8      3565.0     3488.0       3533.4
# 1  2019-01-21 18:00:00      3531.7      3607.5     3440.0       3575.8
# 2  2019-01-22 18:00:00      3575.7      3613.2     3524.2       3556.1
# 3  2019-01-23 18:00:00      3556.1      3591.0     3531.3       3568.3
# 4  2019-01-24 18:00:00      3571.2      3576.6     3511.6       3560.0
#
#      vol_xxbtz  open_xethz  high_xethz  low_xethz  close_xethz     vol_xethz  \
# 0  1547.136188      117.60      118.13     113.51       115.68  37208.703571
# 1  1985.344973      115.75      119.71     110.92       117.88  49974.217966
# 2  2110.964339      117.83      118.89     115.00       116.59  32932.164211
# 3  1735.043844      116.48      117.33     113.68       116.36  35803.327385
# 4  1149.972270      116.39      117.01     114.12       115.08  20757.959761
#
# ...
